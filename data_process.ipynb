# %%
from load_gxsum import load_gxsum

train = load_gxsum('large', split='train[50000:100000]')
valid = load_gxsum('large', split='validation[2750:5500]')
dataset = load_gxsum('large')
# train = dataset['train']
# valid = dataset['validation']
test = load_gxsum('large')
test = test['test']

# %%
print(len(train), len(valid), len(test))
print(dataset)

# %%
with open('datasets/GXSum_large_BRIO/train.source', 'w', newline='\r') as f:
    for i in train:
        f.write(i['document'].replace('\n', ' ') + '\n')

with open('datasets/GXSum_large_BRIO/train.target', 'w', newline='\r') as f:
    for i in train:
        f.write(i['summary'].replace('\n', ' ') + '\n')

with open('datasets/GXSum_large_BRIO/valid.source', 'w', newline='\r') as f:
    for i in valid:
        f.write(i['document'].replace('\n', ' ') + '\n')

with open('datasets/GXSum_large_BRIO/valid.target', 'w', newline='\r') as f:
    for i in valid:
        f.write(i['summary'].replace('\n', ' ') + '\n')

with open('datasets/GXSum_large_BRIO/test.source', 'w', newline='\r') as f:
    for i in test:
        f.write(i['document'].replace('\n', ' ') + '\n')

with open('datasets/GXSum_large_BRIO/test.target', 'w', newline='\r') as f:
    for i in test:
        f.write(i['summary'].replace('\n', ' ') + '\n')
